# %% [markdown]
# Many Diff approaches to DCF.
# Most relevant, widely used: FCFF (Free Cash Flow Firm)
# - Cash Flow: FCFF = Cash flows before debt payments but after reinvestment needs and taxes.
# - Expected growth: In operating income and FCFF
# - Discount rate: Cost of capital

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

figure(figsize=(15, 10), dpi=460)

img = mpimg.imread('data/dcf_summary.png')
imgplot = plt.imshow(img)

plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
